# %% [markdown]
# # **Golden Ball (The Ballon d'Or)**
#
# 1. **Mô tả**:
#
# - Ballon d'Or (Quả Bóng Vàng) là một giải thưởng bóng đá hàng năm do tạp chí France Football trao tặng, được xem là một trong những giải thưởng cá nhân danh giá nhất dành cho các cầu thủ bóng đá. Giải thưởng này đã được trao từ năm 1956, mặc dù từ năm 2010 đến 2015, giải thưởng này đã được hợp nhất tạm thời với giải Cầu thủ xuất sắc nhất thế giới của FIFA và được gọi là FIFA Ballon d'Or. Tuy nhiên, sự hợp tác này đã kết thúc vào năm 2016 và giải thưởng trở lại với tên gọi Ballon d'Or, trong khi FIFA cũng trở lại với giải thưởng hàng năm riêng của mình là The Best FIFA Men's Player.
#
# - Ban đầu, giải thưởng này chỉ dành cho các cầu thủ từ châu Âu và được biết đến rộng rãi như giải Cầu thủ xuất sắc nhất châu Âu. Vào năm 1995, Ballon d'Or đã mở rộng để bao gồm tất cả các cầu thủ từ bất kỳ quốc gia nào miễn là đang chơi bóng tại các câu lạc bộ châu Âu. Đến năm 2007, giải thưởng này đã trở thành một giải thưởng toàn cầu với tất cả các cầu thủ bóng đá chuyên nghiệp trên khắp thế giới đều đủ điều kiện tham gia.
#
# 2. **Ứng dụng**:
#
# - Giải thưởng Ballon d'Or không chỉ có ý nghĩa danh giá mà còn có ảnh hưởng lớn đến sự nghiệp của các cầu thủ bóng đá, bao gồm:
#
# + Công nhận thành tựu cá nhân của các cầu thủ xuất sắc.
# + Nâng cao giá trị thương hiệu và sự công nhận toàn cầu của các cầu thủ.
# + Góp phần thúc đẩy và nâng cao hình ảnh của các câu lạc bộ bóng đá.
#
# 3. **Vấn đề cần giải quyết**:
#
# - Phân tích dữ liệu để tìm hiểu các xu hướng, đặc điểm của các cầu thủ đã giành được giải thưởng Ballon d'Or qua các năm và xác định các yếu tố ảnh hưởng đến việc giành giải thưởng này.
#
# > Thông Tin Các Cột Dữ Liệu (dataset: `balon.xlsx`)
#
# | Tên Cột          | Mô Tả                                        |
# |------------------|----------------------------------------------|
# | Poste            | Vị trí chơi của cầu thủ                      |
# | Match played     | Số trận đấu đã chơi                          |
# | minute Played    | Số phút thi đấu                              |
# | titularisation   | Tỷ lệ đá chính                               |
# | Goal             | Số bàn thắng                                 |
# | PD               | Số đường chuyền kiến tạo                     |
# | Efficacité       | Hiệu suất                                    |
# | Victoire         | Số trận thắng                                |
# | yellow card      | Số thẻ vàng                                  |
# | red card         | Số thẻ đỏ                                    |
# | Palmares         | Số danh hiệu cá nhân và tập thể              |
# | Recompense SOLO  | Số giải thưởng cá nhân                       |
# | classement       | Vị trí xếp hạng                              |

# %% [markdown]
# ## **THỰC HÀNH VÀ ỨNG DỤNG**

# %% [markdown]
# - Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# ### **A. Áp Dụng Kiến Thức Pandas**
# - Thực hành Đọc dữ liệu với file `.xlsx` - Dạng dữ liệu file Excel

# %%
# Đọc dữ liệu từ file Excel
balon = pd.read_excel('./dataset/balon.xlsx')

# Loại bỏ khoảng trắng dư thừa trong tên cột
balon.columns = balon.columns.str.strip()

balon.head(10)
# Out:
#     id  years               player  Age          Team    Poste  Match played  \
# 0  0.0   1990      Lothar Matthäus   29   Inter Milan  Defense            42
# 1  1.0   1990  Salvatore Schillaci   26      Juventus   Attack            53
# 2  2.0   1990     Andreas Brehme\n   30   Inter Milan  Defense            51
# 3  3.0   1991    Jean-Pierre Papin   28     Marseille   Attack            55
# 4  4.0   1991       Darko Pančev\n   26  ER Belegrade   Attack            16
# 5  5.0   1991      Lothar Matthäus   30   Inter Milan  defense            53
# 6  6.0   1992     Marco van Basten   28      Ac Milan   Attack            47
# 7  NaN   1992     Hristo Stoichkov   26  FC Barcelone   Attack            48
# 8  NaN   1992      Dennis Bergkamp   23          Ajax   attack            54
# 9  7.0   1993       Roberto Baggio   26      Juventus  Milieu             49
#
#    minute Played  titularisation  Goal  PD  Efficacité  Victoire  yellow card  \
# ...

# %% [markdown]
# ##### Giải thích:
#
# - `pd.read_excel('/mnt/data/balon.xlsx')`: Sử dụng hàm read_excel của thư viện pandas để đọc dữ liệu từ file Excel và lưu vào biến balon.
# - `balon.head(10)`: Hiển thị 10 dòng đầu tiên của DataFrame balon để xem qua cấu trúc và một phần dữ liệu của file Excel đã được đọc.

# %%
# Kiểm tra kích thước của DataFrame
balon.shape
# Out:
# (90, 18)

# %% [markdown]
# ##### Giải thích:
#
# - `balon.shape`: Trả về một tuple thể hiện kích thước của DataFrame balon, với số hàng và số cột tương ứng.

# %%
# Kiểm tra tên các cột
balon.columns
# Out:
# Index(['id', 'years', 'player', 'Age', 'Team', 'Poste', 'Match played',
#        'minute Played', 'titularisation', 'Goal', 'PD', 'Efficacité',
#        'Victoire', 'yellow card', 'red card', 'Palmares', 'Recompense SOLO',
#        'classement'],
#       dtype='object')

# %% [markdown]
# ##### Giải thích:
#
# - `balon.columns`: Trả về danh sách các tên cột của DataFrame balon.

# %%
# Kiểm tra thông tin tóm tắt về DataFrame
balon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               34 non-null     float64
#  1   years            90 non-null     int64
#  2   player           90 non-null     object
#  3   Age              90 non-null     int64
#  4   Team             90 non-null     object
#  5   Poste            90 non-null     object
#  6   Match played     90 non-null     int64
#  7   minute Played    90 non-null     int64
#  8   titularisation   90 non-null     int64
#  9   Goal             90 non-null     int64
#  10  PD               90 non-null     int64
#  11  Efficacité       89 non-null     float64
#  12  Victoire         90 non-null     int64
#  13  yellow card      90 non-null     int64
#  14  red card         90 non-null     int64
#  15  Palmares         90 non-null     int64
#  16  Recompense SOLO  90 non-null     int64
# ...

# %% [markdown]
# ##### Giải thích:
#
# - `balon.info()`: Hiển thị thông tin tóm tắt về DataFrame balon, bao gồm:
#     + Tổng số lượng hàng (entries).
#     + Tên các cột.
#     + Số lượng giá trị không rỗng (non-null) trong mỗi cột.
#     + Kiểu dữ liệu của mỗi cột (e.g., int64, float64, object).
#     + Dung lượng bộ nhớ mà DataFrame chiếm dụng.

# %%
# Mô tả chi tiết các cột dữ liệu
balon.describe(include='all')
# Out:
#                id        years        player        Age          Team   Poste  \
# count   34.000000    90.000000            90  90.000000            90      90
# unique        NaN          NaN            48        NaN            18       6
# top           NaN          NaN  Lionel Messi        NaN  FC Barcelone  Attack
# freq          NaN          NaN            12        NaN            26      54
# mean    13.441176  2004.500000           NaN  26.922222           NaN     NaN
# std      8.770443     8.703932           NaN   3.212433           NaN     NaN
# min      0.000000  1990.000000           NaN  20.000000           NaN     NaN
# 25%      6.000000  1997.000000           NaN  24.250000           NaN     NaN
# 50%     12.500000  2004.500000           NaN  27.000000           NaN     NaN
# 75%     20.750000  2012.000000           NaN  29.000000           NaN     NaN
# max     29.000000  2019.000000           NaN  35.000000           NaN     NaN
#
# ...

# %% [markdown]
# ##### Giải thích:
#
# - `describe(include='all')`: Cung cấp mô tả chi tiết cho tất cả các cột trong DataFrame, bao gồm cả các cột có kiểu dữ liệu object.

# %% [markdown]
# ### **B. Áp Dụng Kiến Thức Numpy**
#
# #### 1. Basic Numpy Operations

# %%
# Chuyển đổi cột 'Efficacité' thành mảng numpy và tính các thống kê cơ bản
efficacite = balon['Efficacité'].to_numpy()
mean_efficacite = np.nanmean(efficacite)
median_efficacite = np.nanmedian(efficacite)
std_efficacite = np.nanstd(efficacite)
print("Mean Efficacité:", mean_efficacite)
print("Median Efficacité:", median_efficacite)
print("Standard Deviation of Efficacité:", std_efficacite)
# Out:
# Mean Efficacité: 367.7865168539326
# Median Efficacité: 140.0
# Standard Deviation of Efficacité: 601.687411320696

# %% [markdown]
# ##### Giải thích:
#
# - `to_numpy()`: Chuyển đổi cột 'Efficacité' thành mảng numpy.
# - `np.nanmean()`: Tính giá trị trung bình của mảng, bỏ qua các giá trị NaN.
# - `np.nanmedian()`: Tính giá trị trung vị của mảng, bỏ qua các giá trị NaN.
# - `np.nanstd()`: Tính độ lệch chuẩn của mảng, bỏ qua các giá trị NaN.

# %% [markdown]
# #### 2. Handling Missing Values

# %%
# Loại bỏ cột 'id' và kiểm tra các giá trị thiếu trong 'Efficacité'
balon = balon.drop('id', axis=1)
missing_values = balon.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Điền các giá trị thiếu bằng giá trị trung vị của cột 'Efficacité'
balon['Efficacité'] = balon['Efficacité'].fillna(balon['Efficacité'].median())
print("Missing values filled with median.")
# Out:
# Missing values in each column:
#  years              0
# player             0
# Age                0
# Team               0
# Poste              0
# Match played       0
# minute Played      0
# titularisation     0
# Goal               0
# PD                 0
# Efficacité         1
# Victoire           0
# yellow card        0
# red card           0
# Palmares           0
# Recompense SOLO    0
# classement         0
# dtype: int64
# Missing values filled with median.

# %% [markdown]
# ##### Giải thích:
#
# - `drop('id', axis=1)`: Loại bỏ cột 'id' khỏi DataFrame.
# - `isnull().sum()`: Kiểm tra và đếm số lượng giá trị bị thiếu trong mỗi cột.
# - `fillna(balon['Efficacité'].median())`: Điền các giá trị thiếu trong cột 'Efficacité' bằng giá trị trung vị đã tính được.

# %% [markdown]
# #### 3. Data Transformation

# %%
# Biến đổi log của 'Efficacité'
log_efficacite = np.log(balon['Efficacité'])

# Hiển thị dữ liệu đã biến đổi
print("Original Efficacité:", balon['Efficacité'][:5])
print("Log Transformed Efficacité:", log_efficacite[:5])
# Out:
# Original Efficacité: 0    196.0
# 1    171.0
# 2    503.0
# 3    119.0
# 4     91.0
# Name: Efficacité, dtype: float64
# Log Transformed Efficacité: 0    5.278115
# 1    5.141664
# 2    6.220590
# 3    4.779123
# 4    4.510860
# Name: Efficacité, dtype: float64

# %% [markdown]
# ##### Giải thích:
#
# - `np.log()`: Áp dụng phép biến đổi log tự nhiên cho các giá trị trong mảng.

# %% [markdown]
# #### 4. Data Aggregation

# %%
# Tổng hợp 'Efficacité' theo 'Poste'
poste_efficacite = balon.groupby('Poste')['Efficacité'].sum().to_numpy()

# Hiển thị dữ liệu tổng hợp
print("Efficacité by Poste:", poste_efficacite)
# Out:
# Efficacité by Poste: [6631. 9944. 7613. 8381.  133.  171.]

# %% [markdown]
# ##### Giải thích:
#
# - `groupby()`: Nhóm dữ liệu theo 'Poste'.
# - `sum()`: Tính tổng hiệu suất cho từng vị trí chơi.
# - `to_numpy()`: Chuyển đổi kết quả thành mảng numpy.

# %% [markdown]
# #### 5. Data Normalization

# %%
# Chuẩn hóa Min-Max của 'Efficacité'
min_efficacite = np.min(balon['Efficacité'])
max_efficacite = np.max(balon['Efficacité'])
normalized_efficacite = (balon['Efficacité'] - min_efficacite) / (max_efficacite - min_efficacite)
print("Normalized Efficacité:", normalized_efficacite[:5])
# Out:
# Normalized Efficacité: 0    0.039324
# 1    0.031199
# 2    0.139097
# 3    0.014300
# 4    0.005200
# Name: Efficacité, dtype: float64

# %% [markdown]
# ##### Giải thích:
#
# - `np.min()`: Tìm giá trị nhỏ nhất trong mảng.
# - `np.max()`: Tìm giá trị lớn nhất trong mảng.
# - Biểu thức `( balon['Efficacité'] - min_efficacite ) / ( max_efficacite - min_efficacite )`: Áp dụng chuẩn hóa Min-Max cho các giá trị trong mảng.

# %% [markdown]
# ### **C. Thực Hiện Làm Sạch Dữ Liệu - Data Cleaning**

# %%
# Kiểm tra các giá trị bị thiếu
missing_values = balon.isnull().sum()
print("Missing values in each column:\n", missing_values)

# Điền các giá trị thiếu bằng giá trị trung vị của cột tương ứng
balon['Efficacité'] = balon['Efficacité'].fillna(balon['Efficacité'].median())
balon['minute Played'] = balon['minute Played'].fillna(balon['minute Played'].median())
balon['titularisation'] = balon['titularisation'].fillna(balon['titularisation'].median())
balon['Goal'] = balon['Goal'].fillna(balon['Goal'].median())
balon['PD'] = balon['PD'].fillna(balon['PD'].median())
balon['Victoire'] = balon['Victoire'].fillna(balon['Victoire'].median())
balon['yellow card'] = balon['yellow card'].fillna(balon['yellow card'].median())
balon['red card'] = balon['red card'].fillna(balon['red card'].median())
balon['Palmares'] = balon['Palmares'].fillna(balon['Palmares'].median())
balon['Recompense SOLO'] = balon['Recompense SOLO'].fillna(balon['Recompense SOLO'].median())
balon['classement'] = balon['classement'].fillna(balon['classement'].median())

# Xác minh các giá trị bị thiếu đã được xử lý
print("Missing values after filling:\n", balon.isnull().sum())
# Out:
# Missing values in each column:
#  years              0
# player             0
# Age                0
# Team               0
# Poste              0
# Match played       0
# minute Played      0
# titularisation     0
# Goal               0
# PD                 0
# Efficacité         0
# Victoire           0
# yellow card        0
# red card           0
# Palmares           0
# Recompense SOLO    0
# classement         0
# dtype: int64
# Missing values after filling:
#  years              0
# player             0
# Age                0
# Team               0
# Poste              0
# Match played       0
# minute Played      0
# titularisation     0
# Goal               0
# PD                 0
# Efficacité         0
# Victoire           0
# yellow card        0
# red card           0
# Palmares           0
# Recompense SOLO    0
# classement         0
# dtype: int64

# %% [markdown]
# ##### Giải thích:
#
# - `balon.isnull().sum()`: Kiểm tra và đếm số lượng giá trị bị thiếu trong mỗi cột của DataFrame balon.
# - `fillna(median)`: Điền các giá trị thiếu trong mỗi cột bằng giá trị trung vị của cột tương ứng và cập nhật trực tiếp vào DataFrame balon.

# %% [markdown]
# ### **D. Áp Dụng Kiến Thức Matplotlib - Data Visualization**

# %%
# Thiết lập môi trường vẽ biểu đồ
# %matplotlib inline
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = (10, 10)
matplotlib.rcParams['font.size'] = 15

# Vẽ biểu đồ histogram cho toàn bộ các cột trong dataset
balon.hist(figsize=(15, 15), edgecolor='black')
plt.show()

# %% [markdown]
# #### 1. Biểu Đồ Phân Phối Hiệu Suất (Efficacité Distribution)

# %%
plt.figure(figsize=(10, 6))
plt.hist(balon['Efficacité'], bins=30, edgecolor='black')
plt.title('Phân Phối Hiệu Suất')
plt.xlabel('Hiệu Suất')
plt.ylabel('Tần Suất')
plt.show()

# %% [markdown]
# #### 2. Biểu Đồ Box Plot Cho Số Bàn Thắng Theo Vị Trí (Goals by Poste)

# %%
plt.figure(figsize=(12, 8))
balon.boxplot(column='Goal', by='Poste', grid=False)
plt.title('Số Bàn Thắng Theo Vị Trí')
plt.suptitle('')
plt.xlabel('Vị Trí')
plt.ylabel('Số Bàn Thắng')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### 3. Biểu Đồ Scatter Plot Giữa Số Trận Đấu và Hiệu Suất (Match played vs. Efficacité)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(balon['Match played'], balon['Efficacité'], alpha=0.5)
plt.title('Số Trận Đấu vs. Hiệu Suất')
plt.xlabel('Số Trận Đấu')
plt.ylabel('Hiệu Suất')
plt.show()

# %% [markdown]
# #### 4. Biểu Đồ Thanh Cho Số Lần Thắng Theo Vị Trí (Wins by Poste)

# %%
plt.figure(figsize=(10, 6))
balon['Victoire'].value_counts().sort_index().plot(kind='bar', edgecolor='black')
plt.title('Số Lần Thắng Theo Vị Trí')
plt.xlabel('Số Lần Thắng')
plt.ylabel('Tần Suất')
plt.show()

# %% [markdown]
# #### 5. Biểu Đồ Tròn (Pie Chart) Cho Vị Trí Chơi (Poste)

# %%
plt.figure(figsize=(5, 5))
poste_counts = balon['Poste'].value_counts()
plt.pie(poste_counts, labels=poste_counts.index, autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
plt.title('Tỷ Lệ Các Vị Trí Chơi')
plt.axis('equal') # Đảm bảo biểu đồ tròn được vẽ dưới dạng hình tròn
plt.show()

# %% [markdown]
# ##### Giải thích:
#
# - Phân Phối Hiệu Suất (Efficacité Distribution): Vẽ biểu đồ histogram để hiểu rõ hơn về phân phối hiệu suất của các cầu thủ.
# - Box Plot Cho Số Bàn Thắng Theo Vị Trí (Goals by Poste): Vẽ biểu đồ box plot để so sánh số bàn thắng theo từng vị trí chơi.
# - Scatter Plot Giữa Số Trận Đấu và Hiệu Suất (Match played vs. Efficacité): Vẽ biểu đồ scatter plot để thể hiện mối quan hệ giữa số trận đấu đã chơi và hiệu suất.
# - Thanh Cho Số Lần Thắng Theo Vị Trí (Wins by Poste): Vẽ biểu đồ thanh để đếm số lần thắng theo vị trí chơi.
# - Pie Chart Cho Vị Trí Chơi (Poste): Vẽ biểu đồ tròn để hiển thị tỷ lệ các vị trí chơi của các cầu thủ.

# %% [markdown]
# ## PHÂN TÍCH DỮ LIỆU
#
# > Dữ liệu từ bộ dataset 'Ballon d'Or' bao gồm các ghi chép về thành tích của các cầu thủ bóng đá, với các thông tin về vị trí chơi, số trận đấu, số phút thi đấu, số bàn thắng, hiệu suất, số trận thắng, số thẻ vàng, số thẻ đỏ, số danh hiệu cá nhân và tập thể, và vị trí xếp hạng. Việc phân tích dữ liệu từ dataset này sẽ giúp chúng ta có cái nhìn tổng quan về các yếu tố ảnh hưởng đến thành tích và giải thưởng của các cầu thủ.
#
# ### Các bước phân tích dữ liệu:
#
# 1. **Khám phá dữ liệu (Data Exploration):**
#
# - Kiểm tra các giá trị bị thiếu và xử lý chúng.
# - Tính toán các thống kê mô tả cơ bản như trung bình, trung vị, và độ lệch chuẩn cho các biến số.
# - Vẽ các biểu đồ phân phối để hiểu rõ hơn về dữ liệu.
#
# 2. **Phân tích mối quan hệ (Relationship Analysis):**
#
# - Sử dụng biểu đồ scatter plot để phân tích mối quan hệ giữa số trận đấu và hiệu suất.
# - Sử dụng biểu đồ box plot để so sánh số bàn thắng theo vị trí chơi.
# - Sử dụng biểu đồ bar plot để phân tích số lần thắng theo vị trí chơi và các yếu tố khác.
#
# 3. **Chuẩn hóa và biến đổi dữ liệu (Data Transformation and Normalization):**
#
# - Chuẩn hóa các biến số như hiệu suất để đảm bảo dữ liệu nằm trong khoảng hợp lý.
# - Biến đổi các biến số như số bàn thắng để giảm thiểu sự ảnh hưởng của các giá trị ngoại lệ.
#
# 4. **Tạo các biến số mới (Feature Engineering):**
#
# - Tạo các biến số mới từ dữ liệu hiện có, ví dụ như tạo biến số tổng hợp từ số phút thi đấu và hiệu suất để tạo ra chỉ số mới thể hiện mức độ đóng góp của cầu thủ.
#
# ### Lợi ích của việc phân tích dữ liệu với Numpy, Pandas và Matplotlib:
#
# 1. **Numpy:**
#
# - Giúp thực hiện các phép toán nhanh chóng và hiệu quả trên các mảng dữ liệu lớn.
# - Hỗ trợ tính toán các thống kê mô tả cơ bản và nâng cao.
#
# 2. **Pandas:**
#
# - Cung cấp các công cụ mạnh mẽ để thao tác và xử lý dữ liệu, từ việc đọc, ghi dữ liệu đến việc xử lý các giá trị bị thiếu, lọc dữ liệu, và nhóm dữ liệu.
# - Giúp dễ dàng khám phá và phân tích dữ liệu với các phương thức tiện lợi.
#
# 3. **Matplotlib:**
#
# - Giúp trực quan hóa dữ liệu một cách sinh động và dễ hiểu thông qua các biểu đồ đa dạng.
# - Hỗ trợ tạo các biểu đồ tùy chỉnh để phù hợp với các nhu cầu phân tích khác nhau.
#
# ### Tầm quan trọng của phân tích dữ liệu:
#
# Phân tích dữ liệu là một bước quan trọng trong quá trình ra quyết định dựa trên dữ liệu. Đối với một Data Analyst, việc phân tích dữ liệu mang lại những lợi ích sau:
#
# 1. **Hiểu rõ hơn về dữ liệu:**
#
# - Giúp khám phá và hiểu rõ các đặc điểm của dữ liệu, từ đó phát hiện ra các vấn đề và cơ hội tiềm năng.
#
# 2. **Xác định các yếu tố ảnh hưởng:**
#
# - Giúp xác định các yếu tố chính ảnh hưởng đến thành tích của các cầu thủ, từ đó đưa ra các quyết định hợp lý và hiệu quả.
#
# 3. **Dự đoán và tối ưu hóa:**
#
# - Giúp chuẩn bị dữ liệu cho các mô hình dự đoán, từ đó dự đoán chính xác thành tích của các cầu thủ và tối ưu hóa các chiến lược.
#
# 4. **Ra quyết định dựa trên dữ liệu:**
#
# - Cung cấp cơ sở khoa học cho việc ra quyết định, giảm thiểu rủi ro và tăng cường hiệu quả thi đấu.
#
# 5. Nâng cao kỹ năng và hiệu suất làm việc:
#
# - Giúp Data Analyst nâng cao kỹ năng phân tích và trực quan hóa dữ liệu, từ đó cải thiện hiệu suất làm việc và đóng góp tích cực vào sự phát triển của tổ chức.
#
# Qua việc áp dụng các công cụ và kỹ thuật phân tích dữ liệu, chúng ta có thể tối ưu hóa quy trình thi đấu, dự đoán chính xác thành tích của các cầu thủ và đưa ra các quyết định thi đấu hiệu quả, góp phần vào sự thành công của đội bóng và tổ chức.
